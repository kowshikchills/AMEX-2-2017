# %% [markdown]
# # Feature Engineering

# %%
import pandas
def Prepro(df_train):
    return df_train
def encoding(df_train):
    X = []
    if 'target_1' in df_train.columns:
        Y1 = df_train['target_1'].values
        Y2 = df_train['target_2'].values
        del df_train['target_2']
        del df_train['target_1']
        del df_train['cm_key']
        df_tr = df_train[df_train.columns[:43]]
        X = df_tr.to_dict('records')
        from sklearn.feature_extraction import DictVectorizer
        enc = DictVectorizer()
        Xenc =enc.fit_transform(X)
        return [Xenc,Y1,Y2]
    else:
        del df_train['cm_key']
        df_tr = df_train[df_train.columns[:43]]
        X = df_tr.to_dict('records')
        from sklearn.feature_extraction import DictVectorizer
        enc = DictVectorizer()
        Xenc =enc.fit_transform(X)
        return [Xenc]

def encoding2(df_train):
    X = []
    if 'target_1' in df_train.columns:
        Y1 = df_train['target_1'].values
        Y2 = df_train['target_2'].values
        del df_train['target_2']
        del df_train['target_1']
        del df_train['cm_key']
        df_tr = df_train[df_train.columns[:43]]
        X = df_tr.to_dict('records')
        from sklearn.feature_extraction import DictVectorizer
        enc = DictVectorizer()
        Xenc =enc.fit_transform(X)
        return [Xenc,Y1,Y2]
    else:
        df_tr = df_train[df_train.columns[:43]]
        X = df_tr.to_dict('records')
        from sklearn.feature_extraction import DictVectorizer
        enc = DictVectorizer()
        Xenc =enc.fit_transform(X)
        return [Xenc]   
def prepros2(df_train):
    df_train['ElecSt'] =  df_train['mvar16']+df_train['mvar17']+df_train['mvar18']+df_train['mvar19']
    K  = df_train['ElecSt'].values>0
    df_train['ElecB']  = K*1
    for i in [u'mvar16', u'mvar17', u'mvar18',u'mvar19']:
        df_train[i+'R'] = df_train[i]/df_train['ElecSt']
    df_train['TravelSt'] =  df_train['mvar20']+df_train['mvar21']+df_train['mvar22']+df_train['mvar23']
    K  = df_train['TravelSt'].values>0
    df_train['TravelB']  = K*1
    for i in [u'mvar20', u'mvar21', u'mvar22',u'mvar23']:
        df_train[i] = df_train[i]/df_train['TravelSt']
        
    df_train['HouseSt'] =  df_train['mvar24']+df_train['mvar25']+df_train['mvar26']+df_train['mvar27']
    K  = df_train['HouseSt'].values>0
    df_train['HouseB']  = K*1
    for i in [u'mvar24', u'mvar25', u'mvar26',u'mvar27']:
        df_train[i] = df_train[i]/df_train['HouseSt']
    
    
    df_train['CarSt'] =  df_train['mvar28']+df_train['mvar29']+df_train['mvar30']+df_train['mvar31']
    K  = df_train['CarSt'].values>0
    df_train['CarB']  = K*1

    for i in [u'mvar28', u'mvar29', u'mvar30',u'mvar31']:
        df_train[i] = df_train[i]/df_train['CarSt']

    df_train['RetSt'] =  df_train['mvar32']+df_train['mvar33']+df_train['mvar34']+df_train['mvar35']
    K  = df_train['RetSt'].values>0
    df_train['RetB']  = K*1
    for i in [u'mvar32', u'mvar33', u'mvar34',u'mvar35']:
        df_train[i] = df_train[i]/df_train['RetSt']
    df_train['TLC'] = df_train['mvar40']+df_train['mvar41']+df_train['mvar42']+df_train['mvar43']+df_train['mvar44']+df_train['mvar45']
    df_train['TLCcard'] = df_train['mvar43']+ df_train['mvar44']+df_train['mvar45']
    df_train['TLCoffer'] =df_train['mvar40']+ df_train['mvar41']+df_train['mvar42']
    for i in ['TLC','TLCcard','TLCoffer']:
        K  = df_train[i].values>0
        df_train[i+'B']  = K*1 
    
    K  = df_train['mvar3'].values>0 ############
    df_train['mvar3B']  = K*1
    
    K  = df_train['mvar4'].values>4.5 ##########
    df_train['mvar4B']  = K*1

    K  = df_train['mvar5'].values>0
    df_train['mvar5B']  = K*1

    K  = df_train['mvar6'].values>1000
    df_train['mvar6B']  = K*1
    
    K  = df_train['mvar7'].values>0
    df_train['mvar7B']  = K*1

    K  = df_train['mvar8'].values>0
    df_train['mvar8B']  = K*1

    K  = df_train['mvar9'].values>0
    df_train['mvar9B']  = K*1
    
    K  = df_train['mvar15'].values>0
    df_train['mvar15B']  = K*1
    
    df_train['B']  = df_train['mvar3B']+df_train['mvar4B'] +df_train['mvar5B']+df_train['mvar6B'] +df_train['mvar7B']
    
    df_train['TS'] = df_train['mvar36']+df_train['mvar37']+df_train['mvar38']+df_train['mvar39']
    for i in [u'mvar36', u'mvar37', u'mvar38',u'mvar39']:
        df_train[i] = df_train[i]/df_train['TS']
    for i in [0,1,2,3]:
         df_train['q'+str(1+i)] = df_train['mvar'+str(16+i)]+ df_train['mvar'+str(20+i)] + df_train['mvar'+str(24+i)] + df_train['mvar'+str(28+i)] + df_train['mvar'+str(32+i)] +df_train['mvar'+str(36+i)]

    K  = df_train['mvar2'].values<6
    df_train['smallF']  = K*1   
    K  = df_train['mvar2'].values >=6
    df_train['longF']  = K*1   
    df_train  = df_train.fillna(0)
    
    df_train['A']  = df_train['mvar3'] - df_train['TS']
    df_train['B']  = df_train['mvar7']*df_train['TS']
    return df_train
def encoding(df_train):
    X = []
    if 'target_1' in df_train.columns:
        Y1 = df_train['target_1'].values
        Y2 = df_train['target_2'].values
        del df_train['target_2']
        del df_train['target_1']
        del df_train['cm_key']
        df_tr = df_train[df_train.columns[:43]]
        X = df_tr.to_dict('records')
        from sklearn.feature_extraction import DictVectorizer
        enc = DictVectorizer()
        Xenc =enc.fit_transform(X)
        return [Xenc,Y1,Y2]
    else:
        del df_train['cm_key']
        df_tr = df_train[df_train.columns[:43]]
        X = df_tr.to_dict('records')
        from sklearn.feature_extraction import DictVectorizer
        enc = DictVectorizer()
        Xenc =enc.fit_transform(X)
        return [Xenc]

def encoding2(df_train):
    X = []
    if 'target_1' in df_train.columns:
        Y1 = df_train['target_1'].values
        Y2 = df_train['target_2'].values
        del df_train['target_2']
        del df_train['target_1']
        del df_train['cm_key']
        df_tr = df_train[df_train.columns[:43]]
        X = df_tr.to_dict('records')
        from sklearn.feature_extraction import DictVectorizer
        enc = DictVectorizer()
        Xenc =enc.fit_transform(X)
        return [Xenc,Y1,Y2]
    else:
        df_tr = df_train[df_train.columns[:43]]
        X = df_tr.to_dict('records')
        from sklearn.feature_extraction import DictVectorizer
        enc = DictVectorizer()
        Xenc =enc.fit_transform(X)
        return [Xenc]   
def prepros2(df_train):
    for i in [0,1,2,3]:
         df_train['q'+str(1+i)] = df_train['mvar'+str(16+i)]+ df_train['mvar'+str(20+i)] + df_train['mvar'+str(24+i)] + df_train['mvar'+str(28+i)] + df_train['mvar'+str(32+i)] +df_train['mvar'+str(36+i)]
    
    df_train['ElecSt'] =  df_train['mvar16']+df_train['mvar17']+df_train['mvar18']+df_train['mvar19']
    K  = df_train['ElecSt'].values>0
    df_train['ElecB']  = K*1
    for i in [u'mvar16', u'mvar20', u'mvar24',u'mvar28',u'mvar32']:
        df_train[i] = df_train[i]/df_train['q1']
    for i in [u'mvar17', u'mvar21', u'mvar25',u'mvar29',u'mvar33']:
        df_train[i] = df_train[i]/df_train['q2']
    for i in [u'mvar18', u'mvar22', u'mvar26',u'mvar30',u'mvar34']:
        df_train[i] = df_train[i]/df_train['q3']
    for i in [u'mvar19', u'mvar23', u'mvar27',u'mvar31',u'mvar35']:
        df_train[i] = df_train[i]/df_train['q4']
        
    df_train['TravelSt'] =  df_train['mvar20']+df_train['mvar21']+df_train['mvar22']+df_train['mvar23']
    K  = df_train['TravelSt'].values>0
    df_train['TravelB']  = K*1
        
    df_train['HouseSt'] =  df_train['mvar24']+df_train['mvar25']+df_train['mvar26']+df_train['mvar27']
    K  = df_train['HouseSt'].values>0
    df_train['HouseB']  = K*1

    
    
    df_train['CarSt'] =  df_train['mvar28']+df_train['mvar29']+df_train['mvar30']+df_train['mvar31']
    K  = df_train['CarSt'].values>0
    df_train['CarB']  = K*1


    df_train['RetSt'] =  df_train['mvar32']+df_train['mvar33']+df_train['mvar34']+df_train['mvar35']
    K  = df_train['RetSt'].values>0
    df_train['RetB']  = K*1

    
    df_train['TLC'] = df_train['mvar40']+df_train['mvar41']+df_train['mvar42']+df_train['mvar43']+df_train['mvar44']+df_train['mvar45']
    df_train['TLCcard'] = df_train['mvar43']+ df_train['mvar44']+df_train['mvar45']
    df_train['TLCoffer'] =df_train['mvar40']+ df_train['mvar41']+df_train['mvar42']
    for i in ['TLC','TLCcard','TLCoffer']:
        K  = df_train[i].values>0
        df_train[i+'B']  = K*1 
    
    K  = df_train['mvar3'].values>0 ############
    df_train['mvar3B']  = K*1
    
    K  = df_train['mvar4'].values>4.5 ##########
    df_train['mvar4B']  = K*1

    K  = df_train['mvar5'].values>0
    df_train['mvar5B']  = K*1

    K  = df_train['mvar6'].values>1000
    df_train['mvar6B']  = K*1
    
    K  = df_train['mvar7'].values>0
    df_train['mvar7B']  = K*1

    K  = df_train['mvar8'].values>0
    df_train['mvar8B']  = K*1

    K  = df_train['mvar9'].values>0
    df_train['mvar9B']  = K*1
    
    K  = df_train['mvar14'].values>0
    df_train['mvar14B']  = K*1
    
    df_train['B']  = df_train['mvar3B']+df_train['mvar4B'] +df_train['mvar5B']+df_train['mvar6B'] +df_train['mvar7B']
    
    df_train['TS'] = df_train['mvar36']+df_train['mvar37']+df_train['mvar38']+df_train['mvar39']
    for i in [u'mvar36', u'mvar37', u'mvar38',u'mvar39']:
        df_train[i] = df_train[i]/df_train['TS']

    K  = df_train['mvar2'].values<6
    df_train['smallF']  = K*1   
    K  = df_train['mvar2'].values >=6
    df_train['longF']  = K*1   
    df_train  = df_train.fillna(0)
    
    df_train['A']  = df_train['mvar3'] - df_train['TS']
    df_train['B']  = df_train['mvar7']*df_train['TS']
    df_train['C']  = df_train['mvar5']/12
    df_train['D']  = df_train['mvar7']/(df_train['mvar11']+0.0001)
    df_train['E']  = df_train['mvar4']/(df_train['mvar2']+1)
    
    return df_train




score = []
money = 0
def AMEXMETRIC(act,pred,score,money):
    for i in range(len(act)):
        if money < 6000:
            if act[i] == pred[i]:
                score.append(100)
                money  = money+6
            elif act[i] != pred[i] and act[i] !='None':
                score.append(100)
                money  = money+12
            elif act[i] =='None':
                score.append(0)
                money  = money+6
            j = i
    return sum(score),money,j
    
    return df_train




score = []
money = 0
def AMEXMETRIC(act,pred,score,money):
    for i in range(len(act)):
        if money < 6000:
            if act[i] == pred[i]:
                score.append(100)
                money  = money+6
            elif act[i] != pred[i] and act[i] !='None':
                score.append(100)
                money  = money+12
            elif act[i] =='None':
                score.append(0)
                money  = money+6
            j = i
    return sum(score),money,j

cols= [
 'cm_key',
 'mvar2',
 'mvar4',
 'mvar5',
 'mvar6',
 'mvar7',
 'mvar8',
 'mvar9',
 'mvar10',
 'mvar11',
 'mvar12',
 'mvar13',
 'mvar14',
 'mvar15',  
 'mvar16',
#  'mvar17',
#  'mvar18',
#  'mvar19',
#  'mvar20',
#  'mvar21',
#  'mvar22',
#  'mvar23',
#  'mvar24',
#  'mvar25',
#  'mvar26',
#  'mvar27',
#  'mvar28',
#  'mvar29',
#  'mvar30',
#  'mvar31',
#  'mvar32',
#  'mvar33',
#  'mvar34',
#  'mvar35',
 'mvar36',
 'mvar37',
 'mvar38',
 'mvar39',
 'mvar40',
 'mvar41',
 'mvar42',
 'mvar43',
 'mvar44',
 'mvar45',
 'ElecSt',
# 'ElecB',
 'TravelSt',
# 'TravelB',
 'HouseSt',
# 'HouseB',
 'CarSt',
# 'CarB',
 'RetSt',
# 'RetB',
 'TS',
 'longF',
 'smallF',
 'q1',
 'q2',
 'q3',
 'q4',
    'TLCB','TLCofferB','A','B','F'
]

def AMEXTRAIN(df_train,df_valid):
    df_train = prepros2(df_train)
    df_valid = prepros2(df_valid)
    Key1 = df_valid['cm_key'].values
    cols= [
     'cm_key',
     'mvar2',
     'mvar4',
     'mvar5',
     'mvar6',
     'mvar7',
     'mvar8',
     'mvar9',
     'mvar10',
     'mvar11',
     'mvar12',
     'mvar13',
     'mvar14',
     'mvar15',  
     'mvar16',
    #  'mvar17',
    #  'mvar18',
    #  'mvar19',
    #  'mvar20',
    #  'mvar21',
    #  'mvar22',
    #  'mvar23',
    #  'mvar24',
    #  'mvar25',
    #  'mvar26',
    #  'mvar27',
    #  'mvar28',
    #  'mvar29',
    #  'mvar30',
    #  'mvar31',
    #  'mvar32',
    #  'mvar33',
    #  'mvar34',
    #  'mvar35',
     'mvar36',
     'mvar37',
     'mvar38',
     'mvar39',
     'mvar40',
     'mvar41',
     'mvar42',
     'mvar43',
     'mvar44',
     'mvar45',
     'ElecSt',
    # 'ElecB',
     'TravelSt',
    # 'TravelB',
     'HouseSt',
    # 'HouseB',
     'CarSt',
    # 'CarB',
     'RetSt',
    # 'RetB',
     'TS',
     'longF',
     'smallF',
     'q1',
     'q2',
     'q3',
     'q4',
        'TLCB','TLCofferB','A','B','F'
    ]

    df_train = df_train[cols+[ 'target_1', 'target_2']]
    df_valid = df_valid[cols]
    #df_test = df_test[cols]

    df_train = Prepro(df_train)
    df_valid = Prepro(df_valid)
    train = encoding(df_train)
    valid = encoding(df_valid)
    X_tr = train[0]
    Y_tr_1  = train[1]
    Y_tr_2  = train[2]
    X_va = valid[0]


    # #Feature Union
    Y = Y_tr_2
    # pca = PCA(n_components=3)
    # selection = SelectKBest(k=25)
    # modelused = FeatureUnion([("pca", pca), ("univ_select", selection)])
    # X_TR = modelused.fit(X_tr.toarray(), Y).transform(X_tr.toarray())
    # X_VA = modelused.fit(X_tr.toarray(), Y).transform(X_va.toarray())

    X_TR = X_tr
    X_VA = X_va

    clf3 = GradientBoostingClassifier(learning_rate=0.01)#GradientBoostingClassifier(min_samples_leaf=200,max_depth=5,n_estimators=100)
    clf3.fit(X_TR,Y_tr_2)
    clf = GradientBoostingClassifier(learning_rate=0.01)#GradientBoostingClassifier(min_samples_leaf=200,max_depth=5,n_estimators=100)
    clf.fit(X_TR,Y_tr_1)
    return [df_train,df_valid, clf.predict_proba(X_VA.toarray()).T[0],clf3.predict_proba(X_VA.toarray()).T[2]] 

df_train = pandas.read_csv('ATRAIN.csv')#pandas.read_csv('AMTRAIN.csv')
df_test = pandas.read_csv('AVALID.csv')
del df_train['Unnamed: 0']
del df_test['Unnamed: 0']
df_valid = pandas.read_csv('Leaderboard.csv')#pandas.read_csv('AMVALID.csv')
Key1 = df_valid['cm_key'].values

df_train = pandas.concat([df_train,df_test])
from sklearn.utils import shuffle
df_train = shuffle(df_train)
df_train = pandas.concat([df_train[df_train.target_1 == 0][:10000],df_train[df_train.target_1 == 1][:10000]])

df_train = prepros2(df_train)
df_valid = prepros2(df_valid)
Key1 = df_valid['cm_key'].values
cols= [
 'cm_key',
 'mvar2',
 'mvar4',
 'mvar5',
 'mvar6',
 'mvar7',
 'mvar8',
 'mvar9',
 'mvar10',
 'mvar11',
 'mvar12',
 'mvar13',
 'mvar14',
 'mvar15',  
 'mvar16',
#  'mvar17',
#  'mvar18',
#  'mvar19',
#  'mvar20',
#  'mvar21',
#  'mvar22',
#  'mvar23',
#  'mvar24',
#  'mvar25',
#  'mvar26',
#  'mvar27',
#  'mvar28',
#  'mvar29',
#  'mvar30',
#  'mvar31',
#  'mvar32',
#  'mvar33',
#  'mvar34',
#  'mvar35',
 'mvar36',
 'mvar37',
 'mvar38',
 'mvar39',
 'mvar40',
 'mvar41',
 'mvar42',
 'mvar43',
 'mvar44',
 'mvar45',
 'ElecSt',
# 'ElecB',
 'TravelSt',
# 'TravelB',
 'HouseSt',
# 'HouseB',
 'CarSt',
# 'CarB',
 'RetSt',
# 'RetB',
 'TS',
 'longF',
 'smallF',
 'q1',
 'q2',
 'q3',
 'q4',
    'TLCB','TLCofferB','A','B','F','C'
]

df_train = df_train[cols+[ 'target_1', 'target_2']]
df_valid = df_valid[cols]
#df_test = df_test[cols]

df_train = Prepro(df_train)
train = encoding(df_train)
valid = encoding(df_valid)
X_tr = train[0]
Y_tr_1  = train[1]
Y_tr_2  = train[2]
# Out:
# C:\Users\user\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel_launcher.py:188: RuntimeWarning: invalid value encountered in greater
# C:\Users\user\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel_launcher.py:192: RuntimeWarning: invalid value encountered in greater
# C:\Users\user\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel_launcher.py:198: RuntimeWarning: invalid value encountered in greater
# C:\Users\user\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel_launcher.py:203: RuntimeWarning: invalid value encountered in greater

# %%
df_train = pandas.read_csv('ATRAIN.csv')#pandas.read_csv('AMTRAIN.csv')
df_valid = pandas.read_csv('AVALID.csv')
del df_train['Unnamed: 0']
del df_valid['Unnamed: 0']
Key1 = df_valid['cm_key'].values
L1 = df_valid['target_1']
L2 = df_valid['target_2']

from sklearn.utils import shuffle
df_train = shuffle(df_train)
df_train = pandas.concat([df_train[df_train.target_1 == 0][:20000],df_train[df_train.target_1 == 1][:10000],df_train[df_train.target_1 == 1][:10000]])
AM = AMEXTRAIN(df_train,df_valid)
# Out:
# C:\Users\user\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel_launcher.py:188: RuntimeWarning: invalid value encountered in greater
# C:\Users\user\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel_launcher.py:192: RuntimeWarning: invalid value encountered in greater
# C:\Users\user\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel_launcher.py:198: RuntimeWarning: invalid value encountered in greater
# C:\Users\user\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel_launcher.py:203: RuntimeWarning: invalid value encountered in greater

# %%
df_train = AM[0] 
df_valid = AM[1] 
df_valid['proba'] = AM[2]
df_valid['proba2'] = AM[3]
df_valid['proba3'] = df_valid['proba']+5*df_valid['proba2']
df_valid['KEY'] = Key1
df_valid['T'] = L1
df_valid = df_valid.sort_values(['proba3'], ascending=True)
df_valid2 = df_valid[:1000]
df_valid2['AX'] = 1
accuracy_score(df_valid2['AX'].values,df_valid2['T'].values)

# %%
# Out:
#       mvar2  mvar4  mvar5  mvar6    mvar7   mvar8     mvar9  mvar10  mvar11  \
# 528       1      6      5      0   0.1228  0.0000   2918974       0  0.6512
# 6631      1      1      7      0   0.0377  0.0000   2918974       0  0.7674
# 9735      2      4      7      0   0.1899  0.0000   2918974       0  3.3286
# 2040      0     12      6      0   0.7969  0.1831     87153       0  0.9071
# 9754      0      6      5      0   0.7969  0.0000   2918974       0  4.4481
# 8197      0      2      9      0   0.7969  0.1155    169843       0  3.7048
# 5109      0      2      7      0   0.7969  0.0000   2918974       0  5.4675
# 6299      1      2      6      0   1.3043  0.0000   2918974       0  4.0320
# 9534      1      3      8      0   0.1904  0.0000   2918974       0  1.4589
# 7077      5      1     31   3411  10.0000  0.0000   2918974       1  6.8813
# 2789      1      4      9      0   0.1640  0.0000   2918974       0  2.2693
# 6440      0      1      6      0   0.7969  0.3243    253536       0  2.2569
# 2845      0      0     14      0   0.0770  0.0000         0       0  2.7942
# 3501      1      1     11      0   0.2317  0.0000   2918974       0  2.2581
# 5418      0     12      7      0   0.0938  0.3466         0       0  0.5557
# 7115      1      8      7      0   0.0442  0.1155     87153       0  1.6940
# 1336      1      1      5      0   0.1468  0.0000   2918974       0  2.7968
# 6420      6      4    227   3857  10.0000  0.6520  17845299       1  6.9283
# 85        0      3      7      0   0.7969  0.0000   2918974       0  4.3493
# 6588      1     12      5      0   0.1216  0.0000   2918974       0  1.5791
# 9883      0     12      9      0   0.0170  0.0000   2918974       0  4.9150
# 5030      1      3      1   4830   4.6314  0.0000   2918974       0  3.5978
# 3306      2      0      5      0   2.7463  0.0000   2918974       0  4.3828
# 900       0      1      8      0   0.1359  0.1155    112022       0  1.7926
# 7651      0      2     12    245   0.7969  0.1831     90979       0  4.4301
# 4983      0      3     14    981   0.7969  0.1831    104845       1  2.7283
# 7931      9      4     57   2432   3.6112  0.6269  15846000       1  6.2504
# 4467      0      2     62   1030   0.7969  0.1155    118845       1  5.6679
# 9917      0      1     16    981   0.7969  0.1831    175042       1  3.6204
# 5925      0      3     52    981   0.7969  0.0000     49122       1  2.2675
# ...     ...    ...    ...    ...      ...     ...       ...     ...     ...
# 5548      1      3     41    381   0.1612  0.2986    253536       0  4.2968
# 9136      3      6     56   1613   2.0882  0.2310    483303       0  6.7587
# 167       0      1     49   1962   0.4689  0.4817   3671803       0  4.7988
# 6708      6      1    108   3126   1.3330  0.0000   2918974       1  6.1443
# 5366      0      3     47    327   0.7969  0.0000         0       0  2.8069
# 3832      0      2      8   1553   0.7969  0.0000   2918974       0  4.4329
# 6002      0      4     10      0   0.7969  0.2310    344167       0  5.3849
# 9228      4      3    171   4830  10.0000  0.1155    108427       0  6.5668
# 833       0      3     31    474   0.7969  0.1831    293151       0  3.2000
# 2074      0      2     91    941   0.7969  0.5669   3308293       0  2.3756
# 3843      0      4      7    174   0.7969  0.4513    507072       0  1.9576
# 1388      0      1     20    171   0.7969  0.8351  27447826       0  4.6592
# 4127      0      3      6    425   0.3015  0.3662     99612       0  5.7852
# 4271      1      1     51    501   0.5116  0.2682     79230       0  4.7788
# 947       0      2     58   1558   1.7719  0.4142    608903       0  5.4764
# 6391      0      4     88    468   0.7969  0.6344    396150       0  1.3339
# 3954      7      1    139   4246   3.9662  0.7675  17313614       1  5.0620
# 4935      0      1    178    991   0.7969  0.0000     62323       0  4.8115
# 8414      4      4     19   1520   0.5466  0.0000   2918974       0  6.2696
# 8581      0     12     54    201   0.7969  0.1155    126768       0  1.0610
# 1789      0      7     27    381   0.7969  0.4993   3108403       0  6.4037
# 4468      4      2    181   1193   1.4695  0.2310    483303       1  5.6141
# 4824      1      4     15    245   0.2571  0.5723    740827       0  3.5900
# 627       4      4    217    931   0.5463  0.6520   2962691       0  0.0000
# 8461      8      4     89    981   0.7434  0.5430   3134502       1  5.6715
# 6349      0     11     12   1079   0.7969  0.1831    108239       1  2.0628
# 7721      0      4      9      0   0.7969  0.0000   2918974       0  2.5349
# 3164      2      2     55   1406   0.6962  0.0000   2918974       0  5.7207
# 5868      2      5     10   1171   0.8222  0.1831    206649       0  2.0272
# 3062      0      4     98   1635   0.7969  0.0000     38665       1  1.1993
#
#                  mvar12  ...            q4  TLCB  TLCofferB           A  \
# 528           Household  ...       3109.87     0          0     6841.39
# 6631            Unknown  ...          3.45     0          0    -9585.29
# 9735      Misc services  ...       1656.39     0          0   -32076.30
# 2040  Personal services  ...       1526.58     0          0    87068.81
# 9754      Misc services  ...         41.41     0          0   -42929.62
# 8197  Non durable goods  ...       9573.57     0          0  -153194.06
# 5109            Finance  ...      13659.90     1          1  -472191.29
# 6299    Office supplies  ...      18076.07     0          0  -127517.63
# 9534            Unknown  ...       5148.44     0          0   -45398.80
# 7077          Transport  ...    2296308.33     1          1 -8283329.56
# 2789            Finance  ...       5563.32     0          0   -49051.93
# 6440          Household  ...     116473.96     0          0     -109.03
# 2845            Finance  ...       5853.35     0          0   -22764.94
# 3501            Unknown  ...      10263.43     0          0   -66962.55
# 5418            Unknown  ...        942.32     0          0   134534.55
# 7115  Personal services  ...          0.00     0          0    -7506.74
# 1336    Office supplies  ...         20.00     0          0   -12475.54
# 6420      Durable goods  ...    2694652.62     1          1 -6658936.42
# 85              Unknown  ...      37098.56     0          0  -147801.05
# 6588            Unknown  ...        198.32     1          1    51566.58
# 9883            Unknown  ...       7823.98     0          0   108724.34
# 5030            Unknown  ...     272129.52     0          0 -1110638.96
# 3306  Personal services  ...       1214.14     0          0  -390852.62
# 900     Social services  ...      23161.60     0          0    -8042.61
# 7651  Personal services  ...      23792.31     0          0  -171130.87
# 4983      Misc services  ...      40184.66     1          1  -138440.43
# 7931       Construction  ...     504304.93     1          1 -1198333.21
# 4467    Social services  ...     122571.35     0          0  -504795.39
# 9917            Finance  ...      14962.56     0          0   -89779.66
# 5925      Misc services  ...      25805.78     1          1  -116734.86
# ...                 ...  ...           ...   ...        ...         ...
# 5548          Household  ...      13472.82     0          0   -58946.09
# 9136  Non durable goods  ...     101618.95     0          0  -494209.54
# 167       Manufacturing  ...      52606.82     0          0   -78220.95
# 6708      Misc services  ...     525014.32     1          1  -706756.68
# 5366        Consumables  ...      69688.43     0          0    95197.73
# 3832  Non durable goods  ...     129339.56     0          0  -261941.85
# 6002      Entertainment  ...       7710.68     0          0   -39232.23
# 9228      Misc services  ...     212480.61     0          0 -1456600.35
# 833        Construction  ...      34214.55     0          0   -92423.37
# 2074  Non durable goods  ...       9098.16     0          0   -56158.29
# 3843            Unknown  ...      39558.68     1          1   275019.28
# 1388          Transport  ...      25801.11     0          0  -152301.94
# 4127    Office supplies  ...        217.97     0          0    -3141.03
# 4271       Construction  ...      37824.82     0          0  -114644.24
# 947        Construction  ...      85436.40     0          0  -355269.79
# 6391      Misc services  ...      10342.68     0          0    31609.99
# 3954  Personal services  ...     288410.22     0          0  -626238.32
# 4935    Social services  ...      14843.29     0          0  -137200.60
# 8414          Transport  ...     117550.29     1          1  -208417.62
# 8581  Personal services  ...       1081.63     0          0   180319.76
# 1789      Manufacturing  ...     239154.63     1          1  -706554.62
# 4468      Durable goods  ...     113153.21     1          1  -337774.25
# 4824  Personal services  ...      17504.70     0          0   -68676.15
# 627           Transport  ...      32856.40     0          0   -91460.86
# 8461      Manufacturing  ...      82622.53     1          1  -185502.54
# 6349  Personal services  ...      11534.26     0          0   -76426.73
# 7721            Unknown  ...      26653.69     0          0   176926.50
# 3164      Manufacturing  ...      12551.25     0          0   110333.52
# 5868         Automotive  ...      41206.65     0          0  -173667.72
# 3062      Entertainment  ...       6780.34     0          0   -42262.80
#
#                  B   F     proba    proba2    proba3    KEY
# 528   2.223492e+03  12  0.177172  0.066020  0.375231   2112
# 6631  3.613654e+02  12  0.310963  0.049366  0.459062  26832
# 9735  6.091289e+03  12  0.208965  0.086777  0.469296  39202
# 2040  7.298959e+03  12  0.121693  0.117208  0.473316   8152
# 9754  3.421061e+04  12  0.215616  0.086307  0.474537  39275
# 8197  1.220803e+05  12  0.181812  0.112764  0.520105  33120
# 5109  3.762892e+05  12  0.162375  0.123334  0.532376  20687
# 6299  2.221035e+05  12  0.328197  0.069041  0.535321  25476
# 9534  8.643932e+03  12  0.191949  0.129615  0.580793  38405
# 7077  8.283330e+07  12  0.270309  0.114489  0.613775  28667
# 2789  8.044517e+03  12  0.242054  0.127461  0.624438  11286
# 6440  3.153437e+05  12  0.178407  0.153980  0.640347  26025
# 2845  1.752900e+03  12  0.336876  0.104189  0.649442  11506
# 3501  1.551522e+04  12  0.227692  0.142082  0.653940  14173
# 5418  8.028764e+02  12  0.226056  0.142948  0.654899  21951
# 7115  7.256199e+02  12  0.304990  0.132029  0.701078  28789
# 1336  4.708983e+03  12  0.363358  0.112690  0.701429   5312
# 6420  7.093565e+07  12  0.332474  0.131690  0.727542  25935
# 85    2.012826e+05  12  0.193715  0.178144  0.728148    357
# 6588  3.513075e+03  12  0.397322  0.112120  0.733681  26664
# 9883  3.782952e+02  12  0.301118  0.149094  0.748402  39814
# 5030  5.143813e+06  12  0.417829  0.112781  0.756171  20387
# 3306  1.073399e+06  12  0.229795  0.176823  0.760265  13343
# 900   6.662988e+03  12  0.290543  0.162500  0.778045   3631
# 7651  1.363742e+05  12  0.264655  0.172912  0.783390  30923
# 4983  1.103232e+05  12  0.292612  0.171834  0.808113  20211
# 7931  4.385337e+06  12  0.277060  0.177961  0.810942  32025
# 4467  4.022714e+05  12  0.286297  0.175023  0.811364  18075
# 9917  7.154541e+04  12  0.303779  0.170150  0.814230  39977
# 5925  1.526692e+05  12  0.334391  0.160827  0.816872  23998
# ...            ...  ..       ...       ...       ...    ...
# 5548  9.502110e+03  12  0.457822  0.406709  1.677949  22499
# 9136  1.278721e+06  12  0.469599  0.403018  1.678651  36814
# 167   9.383109e+04  12  0.445591  0.411039  1.678709    693
# 6708  9.421067e+05  12  0.503640  0.391785  1.678995  27188
# 5366  1.073267e+05  12  0.464183  0.405140  1.679603  21745
# 3832  2.087415e+05  12  0.442189  0.412787  1.680552  15519
# 6002  5.256530e+04  12  0.420923  0.419902  1.680631  24334
# 9228  1.523425e+07  12  0.484769  0.398791  1.681143  37187
# 833   7.791241e+04  12  0.438776  0.414239  1.681494   3351
# 2074  4.475254e+04  12  0.432211  0.416524  1.681781   8326
# 3843  7.053260e+04  12  0.433602  0.416159  1.682079  15555
# 1388  1.213694e+05  12  0.414192  0.422667  1.682192   5571
# 4127  1.706521e+04  12  0.420854  0.420484  1.682308  16733
# 4271  8.901034e+04  12  0.472532  0.403358  1.682608  17326
# 947   6.295025e+05  12  0.478547  0.401555  1.683212   3813
# 6391  3.913895e+04  12  0.432308  0.417038  1.683422  25847
# 3954  3.543952e+06  12  0.429971  0.418214  1.684614  16034
# 4935  1.336183e+05  12  0.450700  0.411416  1.684948  20008
# 8414  1.139211e+05  12  0.489548  0.398588  1.685310  33923
# 8581  5.411142e+03  12  0.501327  0.394710  1.685457  34659
# 1789  5.630534e+05  12  0.377693  0.436034  1.685794   7178
# 4468  4.963593e+05  12  0.543277  0.381164  1.686770  18078
# 4824  1.765664e+04  12  0.509158  0.392587  1.686919  19539
# 627   8.598481e+04  12  0.461264  0.408742  1.687491   2523
# 8461  1.379026e+05  12  0.487009  0.400384  1.688162  34180
# 6349  6.090446e+04  12  0.466876  0.407257  1.688647  25670
# 7721  5.114305e+04  12  0.427899  0.420251  1.688652  31169
# 3164  8.136592e+04  12  0.449160  0.413233  1.688859  12732
# 5868  1.427896e+05  12  0.466898  0.407818  1.690353  23759
# 3062  3.367923e+04  12  0.458406  0.410793  1.690784  12326
#
# [1000 rows x 45 columns]

# %%
df1 = df_valid.sort_values(['proba'], ascending=True)[:500]
df2 = df_valid.sort_values(['proba2'], ascending=True)[:500]
df3 = df_valid.sort_values(['proba3'], ascending=True)[:500]
df_valid2  = df1.merge(df2).merge(df3)

# %%
df_train = pandas.read_csv('ATRAIN.csv')#pandas.read_csv('AMTRAIN.csv')
df_test = pandas.read_csv('AVALID.csv')
del df_train['Unnamed: 0']
del df_test['Unnamed: 0']
df_train = pandas.concat([df_train,df_test])

df_train = prepros2(df_train)
cols= [
 'cm_key',
 'mvar2',
 'mvar4',
 'mvar5',
 'mvar6',
 'mvar7',
 'mvar8',
 'mvar9',
 'mvar10',
 'mvar11',
 'mvar12',
 'mvar13',
 'mvar14',
 'mvar15',  
 'mvar16',
#  'mvar17',
#  'mvar18',
#  'mvar19',
#  'mvar20',
#  'mvar21',
#  'mvar22',
#  'mvar23',
#  'mvar24',
#  'mvar25',
#  'mvar26',
#  'mvar27',
#  'mvar28',
#  'mvar29',
#  'mvar30',
#  'mvar31',
#  'mvar32',
#  'mvar33',
#  'mvar34',
#  'mvar35',
 'mvar36',
 'mvar37',
 'mvar38',
 'mvar39',
 'mvar40',
 'mvar41',
 'mvar42',
 'mvar43',
 'mvar44',
 'mvar45',
 'ElecSt',
# 'ElecB',
 'TravelSt',
# 'TravelB',
 'HouseSt',
# 'HouseB',
 'CarSt',
# 'CarB',
 'RetSt',
# 'RetB',
 'TS',
 'longF',
 'smallF',
 'q1',
 'q2',
 'q3',
 'q4',
    'TLCB','TLCofferB','A','B','F'
]

df_train = df_train[cols+[ 'target_1', 'target_2']]

df_train = Prepro(df_train)

del df_valid2['KEY']
del df_valid2['proba']
del df_valid2['proba2']
del df_valid2['proba3']

df_train2 = df_train[df_train['target_1'] ==1]
Y_2  = df_train2['target_2'].values

del df_train2['mvar12']
del df_valid2['mvar12']

train = encoding2(df_train2)
valid = encoding2(df_valid2)
X_tr2 = train[0]
X_va2 = valid[0]
# Out:
# C:\Users\user\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel_launcher.py:188: RuntimeWarning: invalid value encountered in greater
# C:\Users\user\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel_launcher.py:192: RuntimeWarning: invalid value encountered in greater
# C:\Users\user\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel_launcher.py:198: RuntimeWarning: invalid value encountered in greater
# C:\Users\user\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel_launcher.py:203: RuntimeWarning: invalid value encountered in greater

# %%
clf2 = GradientBoostingClassifier(min_samples_leaf=100)
clf2.fit(X_tr2,Y_2)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_split=1e-07, min_samples_leaf=100,
#               min_samples_split=2, min_weight_fraction_leaf=0.0,
#               n_estimators=100, presort='auto', random_state=None,
#               subsample=1.0, verbose=0, warm_start=False)

# %%
df_valid2['KEY'] = Key2
df_valid2['pred'] = clf2.predict(X_va2.toarray())

# maxproba = []
# for i in clf.predict_proba(X_va2.toarray()):
#     maxproba.append(max(i))
# df_valid2['M']  = maxproba
# df_valid2 = df_valid2.sort_values(['M'], ascending=False)

df_valid = df_valid2[['KEY','pred']]
from sklearn.utils import shuffle
df_valid = shuffle(df_valid)
df_valid.to_csv('god3.csv',index=False,index_label=False,header=False)
# Out:
# C:\Users\user\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\user\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
clf.predict(X_va2.toarray())[clf.predict_proba(X_va2.toarray()).T[2]>0.7]

# %%
df_valid['proba'] = sig_clf.predict_proba(X_VA.toarray()).T[1]
df_valid['KEY'] = Key1
df_valid = df_valid.sort_values(['proba'], ascending=False)
df_valid2 = df_valid[:1000]
Key2 = df_valid2['KEY'].values
del df_valid2['KEY']
del df_valid2['proba']

df_train['Tar'] = Y_tr_2
df_train['T'] = Y_tr_1
df_train2 = df_train[df_train['T'] ==1]
Y_2  = df_train2['Tar'].values

del df_train2['T']
del df_train2['Tar']
#ENCODING
X_train = df_train2.to_dict('records')
X_test = df_valid2.to_dict('records')
X_tr = []
X_te = []
X_tr.extend(X_train)
X_te.extend(X_test)
X_total = X_tr + X_te
#One Hot Encoding 
enc = DictVectorizer()
X_encoded_total =enc.fit_transform(X_total)
X_tr2 =X_encoded_total[:len(X_tr)]
X_va2 =X_encoded_total[len(X_tr):]

# %%
# Out:
# <1000x72 sparse matrix of type '<type 'numpy.float64'>'
# 	with 24576 stored elements in Compressed Sparse Row format>

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier,AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier,OneVsOneClassifier,OutputCodeClassifier
from sklearn.multioutput import MultiOutputClassifier
from sklearn import svm
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest,chi2,SelectKBest,SelectFromModel
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.naive_bayes import MultinomialNB,BernoulliNB
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier,AdaBoostClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.multiclass import OneVsRestClassifier,OutputCodeClassifier
from sklearn.metrics import confusion_matrix,accuracy_score
from collections import Counter
from sklearn.feature_extraction import DictVectorizer
from sklearn.calibration import CalibratedClassifierCV

# %%
def AMEX(df_train,df_valid,cols):
    Key1 = df_valid['cm_key'].values
    df_train = prepros2(df_train)
    df_valid = prepros2(df_valid)

    df_train = df_train[cols+[ 'target_1', 'target_2']]
    df_valid = df_valid[cols]
    #df_test = df_test[cols]

    df_train = Prepro(df_train)
    df_valid = Prepro(df_valid)
    train = encoding(df_train)
    valid = encoding(df_valid)
    X_tr = train[0]
    Y_tr_1  = train[1]
    Y_tr_2  = train[2]
    X_va = valid[0]


    # #Feature Union
    Y = Y_tr_2
    # pca = PCA(n_components=3)
    # selection = SelectKBest(k=25)
    # modelused = FeatureUnion([("pca", pca), ("univ_select", selection)])
    # X_TR = modelused.fit(X_tr.toarray(), Y).transform(X_tr.toarray())
    # X_VA = modelused.fit(X_tr.toarray(), Y).transform(X_va.toarray())

    X_TR = X_tr
    X_VA = X_va
    clf = GradientBoostingClassifier()
    clf.fit(X_tr,Y_tr_1)
    from sklearn.calibration import CalibratedClassifierCV

    sig_clf = CalibratedClassifierCV(clf, method="sigmoid", cv="prefit")
    sig_clf.fit(X_tr.toarray(), Y_tr_1)

    print confusion_matrix(Y_tr_1, sig_clf.predict(X_tr.toarray()))
    df_valid['proba'] = clf.predict_proba(X_VA.toarray()).T[1]
    df_valid['KEY'] = Key1
    df_valid = df_valid.sort_values(['proba'], ascending=False)
    df_valid2 = df_valid[:1000]
    Key2 = df_valid2['KEY'].values
    del df_valid2['KEY']
    del df_valid2['proba']

    df_train['Tar'] = Y_tr_2
    df_train['T'] = Y_tr_1
    df_train2 = df_train[df_train['T'] ==1]
    Y_2  = df_train2['Tar'].values

    del df_train2['T']
    del df_train2['Tar']

    del df_train2['mvar12']
    del df_valid2['mvar12']

    train = encoding2(df_train2)
    valid = encoding2(df_valid2)
    X_tr2 = train[0]
    X_va2 = valid[0]
    clf = GradientBoostingClassifier(min_samples_leaf=100)
    clf.fit(X_tr2,Y_2)
    df_valid2['KEY'] = Key2
    df_valid2['pred'] = clf.predict(X_va2.toarray())
    return df_valid2

    # maxproba = []
    # for i in clf.predict_proba(X_va2.toarray()):
    #     maxproba.append(max(i))
    # df_valid2['M']  = maxproba
    # df_valid2 = df_valid2.sort_values(['M'], ascending=False)
    #df_valid = df_valid2[['KEY','pred']]
    #df_valid.to_csv('kowshik_pred16.csv',index=False,index_label=False,header=False)

# %%
cols= [
 'cm_key',
 'mvar1',
 'mvar2',
 'mvar4',
 'mvar5',
 'mvar6',
 'mvar7',
 'mvar8',
 'mvar9',
 'mvar10',
 'mvar11',
 'mvar12',
 'mvar13',
 'mvar14',
 'mvar15',
 'mvar16',
 'mvar17',
 'mvar18',
 'mvar19',
 'mvar20',
 'mvar21',
 'mvar22',
 'mvar23',
 'mvar24',
 'mvar25',
 'mvar26',
 'mvar27',
 'mvar28',
 'mvar29',
 'mvar30',
 'mvar31',
 'mvar32',
 'mvar33',
 'mvar34',
 'mvar35',
 'mvar36',
 'mvar37',
 'mvar38',
 'mvar39',
 'mvar40',
 'mvar41',
 'mvar42',
 'mvar43',
 'mvar44',
 'mvar45',
 'ElecSt',
 'ElecB',
 'TravelSt',
 'TravelB',
 'HouseSt',
 'HouseB',
 'CarSt',
 'CarB',
 'RetSt',
 'RetB',
 'TS',
 'SingleF',
 'longF',
 'smallF']
import pandas
df_train = pandas.read_csv('AMTRAIN.csv')#pandas.read_csv('AMTRAIN.csv')
df_test = pandas.read_csv('AMVALID.csv')
del df_train['Unnamed: 0']
del df_test['Unnamed: 0']
df_train = pandas.concat([df_train,df_test])
df_valid = pandas.read_csv('Leaderboard_Dataset.csv')#pandas.read_csv('AMVALID.csv')
df = AMEX(df_train,df_valid,cols)
# Out:
# [[30498   624]
#  [ 7976   902]]
# C:\Users\user\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel_launcher.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\user\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel_launcher.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_v = df[['KEY','pred']]
df_v.to_csv('kowshik_pred16.csv',index=False,index_label=False,header=False)
